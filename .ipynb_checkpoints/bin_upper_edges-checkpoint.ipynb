# %%
import operator
import json
from pprint import pprint
with open('alephVpA.json') as f:
    data = json.load(f)['data']

sbins = data['sbin']
dsbins = data['dsbin']
print(sbins)
# Out:
# [0.0375, 0.1, 0.1375, 0.1625, 0.1875, 0.2125, 0.2375, 0.2625, 0.2875, 0.3125, 0.3375, 0.3625, 0.3875, 0.4125, 0.4375, 0.4625, 0.4875, 0.5125, 0.5375, 0.5625, 0.5875, 0.6125, 0.6375, 0.6625, 0.6875, 0.7125, 0.7375, 0.7625, 0.7875, 0.8125, 0.8375, 0.8625, 0.8875, 0.9125, 0.9375, 0.9625, 0.9875, 1.0125, 1.0375, 1.0625, 1.0875, 1.1125, 1.1375, 1.1625, 1.1875, 1.2125, 1.2375, 1.2625, 1.2875, 1.3125, 1.3375, 1.3625, 1.3875, 1.4125, 1.4375, 1.4625, 1.4875, 1.5125, 1.5375, 1.5625, 1.5875, 1.6125, 1.6375, 1.6625, 1.6875, 1.725, 1.775, 1.825, 1.875, 1.925, 1.975, 2.05, 2.15, 2.25, 2.35, 2.5, 2.7, 2.9, 3.0875, 3.3375]

# %%
bin_upper_edges = list(map(operator.add, sbins, [x * 0.5 for x in dsbins]))
pprint(bin_upper_edges)
# Out:
# [0.075,
#  0.125,
#  0.15000000000000002,
#  0.17500000000000002,
#  0.2,
#  0.225,
#  0.25,
#  0.275,
#  0.3,
#  0.325,
#  0.35000000000000003,
#  0.375,
#  0.4,
#  0.425,
#  0.45,
#  0.47500000000000003,
#  0.5,
#  0.5249999999999999,
#  0.5499999999999999,
#  0.575,
#  0.6,
#  0.625,
#  0.6499999999999999,
#  0.6749999999999999,
#  0.7,
#  0.725,
#  0.75,
#  0.7749999999999999,
#  0.7999999999999999,
#  0.825,
#  0.85,
#  0.875,
#  0.8999999999999999,
#  0.9249999999999999,
#  0.95,
#  0.975,
#  1.0,
#  1.025,
#  1.05,
#  1.075,
#  1.0999999999999999,
#  1.125,
#  1.15,
#  1.175,
#  1.2,
#  1.2249999999999999,
#  1.25,
#  1.275,
#  1.3,
#  1.325,
#  1.3499999999999999,
#  1.375,
#  1.4,
#  1.425,
#  1.45,
#  1.4749999999999999,
#  1.5,
#  1.525,
#  1.55,
#  1.575,
#  1.5999999999999999,
#  1.625,
#  1.65,
#  1.675,
#  1.7,
#  1.75,
#  1.7999999999999998,
#  1.8499999999999999,
#  1.9,
#  1.95,
#  2.0,
#  2.0999999999999996,
#  2.1999999999999997,
#  2.3,
#  2.4,
#  2.6,
# ...
