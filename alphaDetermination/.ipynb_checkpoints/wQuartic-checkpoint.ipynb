# %%
exec(open('initNotebook.py').read())

# %% [markdown]
# # Load Data

# %%
quarticAlD6D8 = read_csv('../../FESR/configurations/2019/wQuarticAlphaD6D8/fits.csv')
# quarticAlD6D8D10 = read_csv('../../FESR/configurations/2019/wQuarticAlphaD6D8D10/fits.csv')
quarticAlD6D8D10D12 = read_csv('../../FESR/configurations/2019/wQuarticAlphaD6D8D10D12/fits.csv')
quarticD6D8 = read_csv('../../FESR/configurations/2019/wQuarticD6D8/fits.csv')
quarticD6D8D10 = read_csv('../../FESR/configurations/2019/wQuarticD6D8D10/fits.csv')
quarticD6D8D10D12 = read_csv('../../FESR/configurations/2019/wQuarticD6D8D10D12/fits.csv')

# %%
fig, (axes) = plt.subplots(2, 2, sharex=True)
fig.suptitle(r'Fit of $\omega_{Quartic}$ with free $\alpha_s$ and three different setups of the OPE using FOPT.')
plt.xticks(list(sminMap.values()), fontsize=22)
addAx(axes[0], 0, ['alpha'], quarticAlD6D8, ylabel=r'$\alpha_s(m_\tau)$')
# addAx(axes[1], 0, ['alpha'], quarticAlD6D8D10, ylabel=r'$\alpha_s(m_\tau)$')
addAx(axes[1], 0, ['alpha'], quarticAlD6D8D10D12, ylabel=r'$\alpha_s(m_\tau)$')

addAx(axes[0], 1, ['c6', 'c8'], quarticAlD6D8, ylabel='$D6, D8$')
# addAx(axes[1], 1, ['c6', 'c8', 'c10'], quarticAlD6D8D10, ylabel=r'$D6, D8, D10$')
addAx(axes[1], 1, ['c6', 'c8', 'c10', 'c12'], quarticAlD6D8D10D12, ylabel=r'$D6, D8, D10, D12$')

fig.savefig('./plots/quarticAlpha.png', dpi=300)
plt.show()
