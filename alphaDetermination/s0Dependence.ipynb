# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.genfromtxt('../configurations/oneWeightDifferentNumsOfS0/w1/fits.csv', delimiter=',', skip_header=2)
s0Vec = np.arange(4, 21, 1)
asVec = data[:,1]
dofChi2Vec = data[:,11]

# %%
fig, ax = plt.subplots()
ax.plot(s0Vec, dofChi2Vec)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(s0Vec, asVec)
plt.show()

# %%
import numpy as np
print('ok')
# Out:
# ok
